# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
# !pip install citipy
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# Requirement already satisfied: citipy in c:\users\14043\downloads\newfolder\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\14043\downloads\newfolder\lib\site-packages (from citipy) (0.16)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
#
# > **HINT:** The OpenWeatherMap API only allows 60 calls per minute under their free plan. Try using `time.sleep(60)` after each set of 50 cities to avoid API errors due to large calls.

# %%
#Get URl and store
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Set empty lists to gather information
Cityname = []
Latlist = []
Lnglist = []
Maxtemplist = []
Humlist = []
Cloudlist = []
Windlist = []
Countrylist = []
Datelist = []

#Set index amount
Begin = 0
ChangeVary = 1


#Start loop to gather information
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get (query_url + city).json()
        Cityname.append(response["name"])
        Latlist.append(response["coord"]["lat"])
        Lnglist.append(response["coord"]["lon"])
        Maxtemplist.append(response["main"]["temp_max"])
        Humlist.append(response["main"]["humidity"])
        Cloudlist.append(response["clouds"]["all"])
        Windlist.append(response["wind"]["speed"])
        Countrylist.append(response["sys"]["country"])
        Datelist.append(response["dt"])
        if Begin > 49:
            Begin = 0
            ChangeVary = ChangeVary + 1
        
        else:
            Begin = Begin + 1
            print(f"Processing request number {Begin} of {ChangeVary} | {city}")     
        
    except(KeyError, IndexError):
        print("City not found.")
        
#I was having issues using the time.sleep(60) so instead I used if to reset after 50 iterations through the list
# Out:
# Processing request number 1 of 1 | bethel
# Processing request number 2 of 1 | rikitea
# Processing request number 3 of 1 | mataura
# Processing request number 4 of 1 | nikolskoye
# Processing request number 5 of 1 | mindelo
# Processing request number 6 of 1 | nanortalik
# Processing request number 7 of 1 | atuona
# Processing request number 8 of 1 | sabang
# Processing request number 9 of 1 | tasiilaq
# Processing request number 10 of 1 | hermanus
# Processing request number 11 of 1 | vaini
# Processing request number 12 of 1 | new norfolk
# Processing request number 13 of 1 | ribeira grande
# Processing request number 14 of 1 | talaya
# Processing request number 15 of 1 | lompoc
# City not found.
# City not found.
# Processing request number 16 of 1 | puerto ayora
# Processing request number 17 of 1 | butaritari
# Processing request number 18 of 1 | victoria
# City not found.
# Processing request number 19 of 1 | tuktoyaktuk
# City not found.
# Processing request number 20 of 1 | college
# Processing request number 21 of 1 | bambous virieux
# Processing request number 22 of 1 | bredasdorp
# Processing request number 23 of 1 | carnarvon
# Processing request number 24 of 1 | macapa
# Processing request number 25 of 1 | barrow
# Processing request number 26 of 1 | pimentel
# Processing request number 27 of 1 | gimli
# City not found.
# Processing request number 28 of 1 | isangel
# Processing request number 29 of 1 | korem
# Processing request number 30 of 1 | tessalit
# Processing request number 31 of 1 | charters towers
# Processing request number 32 of 1 | quatre cocos
# Processing request number 33 of 1 | kodiak
# Processing request number 34 of 1 | takoradi
# Processing request number 35 of 1 | takahagi
# Processing request number 36 of 1 | cabedelo
# Processing request number 37 of 1 | pecos
# Processing request number 38 of 1 | bom jesus
# Processing request number 39 of 1 | saint anthony
# Processing request number 40 of 1 | san quintin
# Processing request number 41 of 1 | cape town
# Processing request number 42 of 1 | jamestown
# Processing request number 43 of 1 | sitka
# Processing request number 44 of 1 | waipawa
# Processing request number 45 of 1 | lebu
# City not found.
# Processing request number 46 of 1 | beringovskiy
# Processing request number 47 of 1 | rawson
# Processing request number 48 of 1 | punta arenas
# Processing request number 49 of 1 | saldanha
# Processing request number 50 of 1 | vila franca do campo
# Processing request number 1 of 2 | ushuaia
# Processing request number 2 of 2 | margate
# City not found.
# Processing request number 3 of 2 | ust-tarka
# Processing request number 4 of 2 | bonavista
# Processing request number 5 of 2 | aktau
# Processing request number 6 of 2 | cabo san lucas
# Processing request number 7 of 2 | mount isa
# Processing request number 8 of 2 | vardo
# Processing request number 9 of 2 | port elizabeth
# Processing request number 10 of 2 | eureka
# Processing request number 11 of 2 | dingle
# Processing request number 12 of 2 | igarka
# Processing request number 13 of 2 | khasan
# Processing request number 14 of 2 | labuhan
# Processing request number 15 of 2 | saskylakh
# Processing request number 16 of 2 | qaanaaq
# Processing request number 17 of 2 | khovu-aksy
# Processing request number 18 of 2 | saint-philippe
# Processing request number 19 of 2 | yellowknife
# Processing request number 20 of 2 | upernavik
# Processing request number 21 of 2 | henties bay
# Processing request number 22 of 2 | shimoda
# Processing request number 23 of 2 | san juan
# Processing request number 24 of 2 | lasa
# Processing request number 25 of 2 | khatanga
# Processing request number 26 of 2 | hobart
# Processing request number 27 of 2 | ahipara
# Processing request number 28 of 2 | panara
# Processing request number 29 of 2 | georgiyevka
# Processing request number 30 of 2 | hachinohe
# Processing request number 31 of 2 | port blair
# Processing request number 32 of 2 | busselton
# Processing request number 33 of 2 | kalisz
# Processing request number 34 of 2 | katherine
# Processing request number 35 of 2 | codrington
# Processing request number 36 of 2 | egvekinot
# City not found.
# Processing request number 37 of 2 | tura
# City not found.
# Processing request number 38 of 2 | santo antonio do taua
# Processing request number 39 of 2 | santa vitoria
# Processing request number 40 of 2 | ondjiva
# Processing request number 41 of 2 | arraial do cabo
# Processing request number 42 of 2 | kahului
# Processing request number 43 of 2 | bogorodskoye
# Processing request number 44 of 2 | doha
# City not found.
# Processing request number 45 of 2 | chokurdakh
# Processing request number 46 of 2 | saint george
# Processing request number 47 of 2 | hailar
# Processing request number 48 of 2 | kuvandyk
# Processing request number 49 of 2 | avarua
# Processing request number 50 of 2 | przhevalskoye
# Processing request number 1 of 3 | pevek
# Processing request number 2 of 3 | leningradskiy
# Processing request number 3 of 3 | airai
# Processing request number 4 of 3 | varhaug
# Processing request number 5 of 3 | panaba
# Processing request number 6 of 3 | san jose
# Processing request number 7 of 3 | dongkan
# Processing request number 8 of 3 | tiksi
# City not found.
# Processing request number 9 of 3 | bengkulu
# Processing request number 10 of 3 | tagab
# Processing request number 11 of 3 | nevers
# City not found.
# Processing request number 12 of 3 | ornskoldsvik
# Processing request number 13 of 3 | riyadh
# Processing request number 14 of 3 | sur
# Processing request number 15 of 3 | bluff
# Processing request number 16 of 3 | kashi
# Processing request number 17 of 3 | norman wells
# Processing request number 18 of 3 | bintulu
# Processing request number 19 of 3 | ponta pora
# Processing request number 20 of 3 | provideniya
# Processing request number 21 of 3 | ponta do sol
# Processing request number 22 of 3 | husavik
# Processing request number 23 of 3 | seydi
# Processing request number 24 of 3 | east london
# Processing request number 25 of 3 | chiredzi
# Processing request number 26 of 3 | sault sainte marie
# Processing request number 27 of 3 | castro
# Processing request number 28 of 3 | cherskiy
# Processing request number 29 of 3 | camacha
# Processing request number 30 of 3 | grindavik
# Processing request number 31 of 3 | gat
# Processing request number 32 of 3 | inhambane
# Processing request number 33 of 3 | parkersburg
# Processing request number 34 of 3 | pacific grove
# Processing request number 35 of 3 | mumford
# Processing request number 36 of 3 | kapaa
# Processing request number 37 of 3 | mahebourg
# Processing request number 38 of 3 | clyde river
# Processing request number 39 of 3 | albany
# Processing request number 40 of 3 | fier
# Processing request number 41 of 3 | vanimo
# Processing request number 42 of 3 | sandakan
# Processing request number 43 of 3 | olafsvik
# Processing request number 44 of 3 | medea
# Processing request number 45 of 3 | mishelevka
# Processing request number 46 of 3 | magway
# City not found.
# Processing request number 47 of 3 | scarborough
# Processing request number 48 of 3 | sivaki
# Processing request number 49 of 3 | darhan
# Processing request number 50 of 3 | krasnoselkup
# Processing request number 1 of 4 | seoul
# Processing request number 2 of 4 | thompson
# Processing request number 3 of 4 | dobrinka
# Processing request number 4 of 4 | roald
# City not found.
# Processing request number 5 of 4 | guerrero negro
# Processing request number 6 of 4 | nome
# Processing request number 7 of 4 | havelock
# Processing request number 8 of 4 | batagay
# Processing request number 9 of 4 | geraldton
# Processing request number 10 of 4 | saint-georges
# Processing request number 11 of 4 | broome
# Processing request number 12 of 4 | te anau
# Processing request number 13 of 4 | jining
# Processing request number 14 of 4 | hasaki
# City not found.
# Processing request number 15 of 4 | caravelas
# Processing request number 16 of 4 | orizona
# Processing request number 17 of 4 | pangnirtung
# Processing request number 18 of 4 | bestobe
# Processing request number 19 of 4 | flers
# Processing request number 20 of 4 | portland
# Processing request number 21 of 4 | ixtapa
# Processing request number 22 of 4 | manzanillo
# Processing request number 23 of 4 | bud
# Processing request number 24 of 4 | inuvik
# Processing request number 25 of 4 | molina
# Processing request number 26 of 4 | mata grande
# Processing request number 27 of 4 | kon tum
# Processing request number 28 of 4 | chuy
# Processing request number 29 of 4 | krutinka
# Processing request number 30 of 4 | chokwe
# Processing request number 31 of 4 | pontypool
# Processing request number 32 of 4 | bakchar
# Processing request number 33 of 4 | saint-francois
# Processing request number 34 of 4 | laurel
# Processing request number 35 of 4 | changji
# Processing request number 36 of 4 | houma
# Processing request number 37 of 4 | srednekolymsk
# Processing request number 38 of 4 | quelimane
# Processing request number 39 of 4 | hambantota
# Processing request number 40 of 4 | witu
# City not found.
# Processing request number 41 of 4 | esperance
# Processing request number 42 of 4 | maniitsoq
# Processing request number 43 of 4 | poum
# Processing request number 44 of 4 | salaga
# Processing request number 45 of 4 | ryotsu
# Processing request number 46 of 4 | klaksvik
# Processing request number 47 of 4 | torbay
# Processing request number 48 of 4 | panzhihua
# Processing request number 49 of 4 | bichura
# Processing request number 50 of 4 | itupiranga
# Processing request number 1 of 5 | aklavik
# Processing request number 2 of 5 | flinders
# Processing request number 3 of 5 | cidreira
# Processing request number 4 of 5 | lubao
# City not found.
# Processing request number 5 of 5 | valdivia
# Processing request number 6 of 5 | dicabisagan
# Processing request number 7 of 5 | kenai
# City not found.
# Processing request number 8 of 5 | cap malheureux
# Processing request number 9 of 5 | grand gaube
# Processing request number 10 of 5 | dong xoai
# Processing request number 11 of 5 | nouadhibou
# Processing request number 12 of 5 | luderitz
# Processing request number 13 of 5 | port alfred
# Processing request number 14 of 5 | atar
# Processing request number 15 of 5 | srandakan
# Processing request number 16 of 5 | palmer
# Processing request number 17 of 5 | superior
# Processing request number 18 of 5 | avera
# Processing request number 19 of 5 | bonthe
# Processing request number 20 of 5 | moryakovskiy zaton
# Processing request number 21 of 5 | aksarka
# Processing request number 22 of 5 | rio gallegos
# Processing request number 23 of 5 | ukiah
# City not found.
# Processing request number 24 of 5 | hazro
# Processing request number 25 of 5 | talnakh
# Processing request number 26 of 5 | itarema
# Processing request number 27 of 5 | caledon
# Processing request number 28 of 5 | formosa do rio preto
# Processing request number 29 of 5 | astana
# Processing request number 30 of 5 | hurghada
# Processing request number 31 of 5 | kumluca
# Processing request number 32 of 5 | akyab
# Processing request number 33 of 5 | stornoway
# Processing request number 34 of 5 | ancud
# Processing request number 35 of 5 | poros
# Processing request number 36 of 5 | talcahuano
# Processing request number 37 of 5 | maceio
# Processing request number 38 of 5 | prince george
# Processing request number 39 of 5 | dourbali
# City not found.
# Processing request number 40 of 5 | karratha
# City not found.
# Processing request number 41 of 5 | kavieng
# Processing request number 42 of 5 | saint-paul
# Processing request number 43 of 5 | narsaq
# Processing request number 44 of 5 | port macquarie
# Processing request number 45 of 5 | namatanai
# City not found.
# Processing request number 46 of 5 | nelson bay
# Processing request number 47 of 5 | omsukchan
# Processing request number 48 of 5 | mar del plata
# Processing request number 49 of 5 | hofn
# Processing request number 50 of 5 | muros
# Processing request number 1 of 6 | evanton
# Processing request number 2 of 6 | iaciara
# Processing request number 3 of 6 | yekaterinoslavka
# Processing request number 4 of 6 | mmathubudukwane
# City not found.
# Processing request number 5 of 6 | walvis bay
# Processing request number 6 of 6 | havre-saint-pierre
# Processing request number 7 of 6 | zunyi
# City not found.
# City not found.
# Processing request number 8 of 6 | jiuquan
# Processing request number 9 of 6 | bahia blanca
# Processing request number 10 of 6 | sioux lookout
# Processing request number 11 of 6 | black river
# Processing request number 12 of 6 | baghdad
# Processing request number 13 of 6 | manosque
# Processing request number 14 of 6 | gavrilov posad
# Processing request number 15 of 6 | zaykovo
# Processing request number 16 of 6 | atakpame
# Processing request number 17 of 6 | behshahr
# Processing request number 18 of 6 | yulara
# Processing request number 19 of 6 | fairbanks
# Processing request number 20 of 6 | monterey
# Processing request number 21 of 6 | milkovo
# Processing request number 22 of 6 | balykshi
# Processing request number 23 of 6 | ostrovnoy
# Processing request number 24 of 6 | levelland
# Processing request number 25 of 6 | hauterive
# Processing request number 26 of 6 | gamba
# Processing request number 27 of 6 | sao filipe
# Processing request number 28 of 6 | kondoa
# Processing request number 29 of 6 | tromso
# Processing request number 30 of 6 | beidao
# Processing request number 31 of 6 | boueni
# Processing request number 32 of 6 | sungurlu
# Processing request number 33 of 6 | bara
# Processing request number 34 of 6 | sistranda
# Processing request number 35 of 6 | yerbogachen
# Processing request number 36 of 6 | jilin
# Processing request number 37 of 6 | dikson
# Processing request number 38 of 6 | vostok
# Processing request number 39 of 6 | novoagansk
# Processing request number 40 of 6 | souillac
# Processing request number 41 of 6 | la rioja
# Processing request number 42 of 6 | manga
# Processing request number 43 of 6 | front royal
# Processing request number 44 of 6 | wukari
# Processing request number 45 of 6 | puspokladany
# Processing request number 46 of 6 | jaen
# Processing request number 47 of 6 | lagoa
# City not found.
# Processing request number 48 of 6 | aripuana
# Processing request number 49 of 6 | cowra
# Processing request number 50 of 6 | chapais
# Processing request number 1 of 7 | astara
# Processing request number 2 of 7 | solnechnyy
# Processing request number 3 of 7 | eaglesham
# City not found.
# Processing request number 4 of 7 | korla
# City not found.
# Processing request number 5 of 7 | tilichiki
# Processing request number 6 of 7 | juneau
# Processing request number 7 of 7 | qasigiannguit
# Processing request number 8 of 7 | paris
# City not found.
# Processing request number 9 of 7 | athabasca
# Processing request number 10 of 7 | lamu
# Processing request number 11 of 7 | alofi
# Processing request number 12 of 7 | erzin
# Processing request number 13 of 7 | sibu
# Processing request number 14 of 7 | maki
# Processing request number 15 of 7 | georgetown
# Processing request number 16 of 7 | zhigansk
# Processing request number 17 of 7 | haines junction
# Processing request number 18 of 7 | santa cruz del sur
# Processing request number 19 of 7 | thinadhoo
# Processing request number 20 of 7 | morant bay
# Processing request number 21 of 7 | salalah
# Processing request number 22 of 7 | half moon bay
# Processing request number 23 of 7 | nadigaon
# Processing request number 24 of 7 | opuwo
# Processing request number 25 of 7 | orlik
# Processing request number 26 of 7 | luckenwalde
# Processing request number 27 of 7 | dunda
# Processing request number 28 of 7 | brae
# Processing request number 29 of 7 | salym
# Processing request number 30 of 7 | faanui
# Processing request number 31 of 7 | necochea
# Processing request number 32 of 7 | soyo
# Processing request number 33 of 7 | lata
# Processing request number 34 of 7 | tuatapere
# Processing request number 35 of 7 | genhe
# Processing request number 36 of 7 | pala
# Processing request number 37 of 7 | baculin
# Processing request number 38 of 7 | ulladulla
# Processing request number 39 of 7 | san patricio
# Processing request number 40 of 7 | ipixuna
# Processing request number 41 of 7 | sembe
# Processing request number 42 of 7 | jurado
# Processing request number 43 of 7 | mackenzie
# Processing request number 44 of 7 | krivogastani
# Processing request number 45 of 7 | santa cruz cabralia
# Processing request number 46 of 7 | axim
# Processing request number 47 of 7 | chara
# Processing request number 48 of 7 | nouakchott
# Processing request number 49 of 7 | coquimbo
# Processing request number 50 of 7 | cartagena
# Processing request number 1 of 8 | mandan
# Processing request number 2 of 8 | puerto escondido
# Processing request number 3 of 8 | puerto leguizamo
# Processing request number 4 of 8 | nara
# Processing request number 5 of 8 | abaza
# Processing request number 6 of 8 | luanda
# Processing request number 7 of 8 | laguna
# Processing request number 8 of 8 | sao gabriel da cachoeira
# Processing request number 9 of 8 | ishurdi
# Processing request number 10 of 8 | rumoi
# Processing request number 11 of 8 | nortelandia
# Processing request number 12 of 8 | bacolod
# Processing request number 13 of 8 | kaitangata
# Processing request number 14 of 8 | novorzhev
# Processing request number 15 of 8 | taltal
# Processing request number 16 of 8 | kulhudhuffushi
# Processing request number 17 of 8 | lilongwe
# Processing request number 18 of 8 | pekalongan
# Processing request number 19 of 8 | bousse
# Processing request number 20 of 8 | palauig
# Processing request number 21 of 8 | ponta delgada
# Processing request number 22 of 8 | esmeraldas
# City not found.
# Processing request number 23 of 8 | araouane
# Processing request number 24 of 8 | hualmay
# Processing request number 25 of 8 | aban
# Processing request number 26 of 8 | ust-ishim
# Processing request number 27 of 8 | yarada
# Processing request number 28 of 8 | pedernales
# Processing request number 29 of 8 | spassk-dalniy
# City not found.
# City not found.
# Processing request number 30 of 8 | hilo
# Processing request number 31 of 8 | belaya gora
# Processing request number 32 of 8 | jiangmen
# Processing request number 33 of 8 | hervey bay
# Processing request number 34 of 8 | chenove
# Processing request number 35 of 8 | udachnyy
# Processing request number 36 of 8 | duiwelskloof
# Processing request number 37 of 8 | iqaluit
# Processing request number 38 of 8 | vila
# Processing request number 39 of 8 | namibe
# Processing request number 40 of 8 | formello
# Processing request number 41 of 8 | puerto carreno
# Processing request number 42 of 8 | motygino
# Processing request number 43 of 8 | myitkyina
# Processing request number 44 of 8 | usinsk
# Processing request number 45 of 8 | terney
# Processing request number 46 of 8 | yatou
# Processing request number 47 of 8 | rosarito
# Processing request number 48 of 8 | leh
# Processing request number 49 of 8 | florianopolis
# Processing request number 50 of 8 | vung tau
# Processing request number 1 of 9 | christchurch
# Processing request number 2 of 9 | alpena
# Processing request number 3 of 9 | sawtell
# Processing request number 4 of 9 | tarma
# Processing request number 5 of 9 | estreito
# Processing request number 6 of 9 | kangaba
# Processing request number 7 of 9 | valley city
# Processing request number 8 of 9 | kloulklubed
# Processing request number 9 of 9 | pemangkat
# Processing request number 10 of 9 | port-gentil
# Processing request number 11 of 9 | morag
# Processing request number 12 of 9 | tongzi
# Processing request number 13 of 9 | yanam
# Processing request number 14 of 9 | caceres
# Processing request number 15 of 9 | urengoy
# Processing request number 16 of 9 | prince rupert
# Processing request number 17 of 9 | hamilton
# City not found.
# Processing request number 18 of 9 | mkuranga
# Processing request number 19 of 9 | port-cartier
# Processing request number 20 of 9 | cairns
# City not found.
# Processing request number 21 of 9 | linkoping
# Processing request number 22 of 9 | birjand
# Processing request number 23 of 9 | bata
# Processing request number 24 of 9 | maryborough
# Processing request number 25 of 9 | klimovo
# Processing request number 26 of 9 | lander
# Processing request number 27 of 9 | nalut
# City not found.
# Processing request number 28 of 9 | monster
# Processing request number 29 of 9 | harper
# City not found.
# Processing request number 30 of 9 | ilulissat
# Processing request number 31 of 9 | dunedin
# Processing request number 32 of 9 | itoman
# Processing request number 33 of 9 | porto novo
# Processing request number 34 of 9 | bubaque
# Processing request number 35 of 9 | palaikastron
# Processing request number 36 of 9 | grand valley
# Processing request number 37 of 9 | teknaf
# Processing request number 38 of 9 | taoudenni
# Processing request number 39 of 9 | vestmannaeyjar
# Processing request number 40 of 9 | cedral
# Processing request number 41 of 9 | iwakuni
# Processing request number 42 of 9 | upington
# Processing request number 43 of 9 | ngunguru
# Processing request number 44 of 9 | marsaxlokk
# Processing request number 45 of 9 | hobbs
# Processing request number 46 of 9 | mount gambier
# Processing request number 47 of 9 | morondava
# Processing request number 48 of 9 | severo-kurilsk
# Processing request number 49 of 9 | port lincoln
# Processing request number 50 of 9 | banjar
# Processing request number 1 of 10 | katsuura
# Processing request number 2 of 10 | alamosa
# Processing request number 3 of 10 | jishou
# Processing request number 4 of 10 | ridgecrest
# Processing request number 5 of 10 | jinchang
# Processing request number 6 of 10 | alta floresta
# Processing request number 7 of 10 | barra patuca
# Processing request number 8 of 10 | vallenar
# Processing request number 9 of 10 | constitucion
# City not found.
# Processing request number 10 of 10 | paamiut
# Processing request number 11 of 10 | kalabo
# Processing request number 12 of 10 | lunel
# Processing request number 13 of 10 | surin
# Processing request number 14 of 10 | yinchuan
# Processing request number 15 of 10 | zhaotong
# Processing request number 16 of 10 | sapernoye
# City not found.
# Processing request number 17 of 10 | pecanha
# Processing request number 18 of 10 | ouallam
# Processing request number 19 of 10 | honningsvag
# Processing request number 20 of 10 | kununurra
# Processing request number 21 of 10 | povoa de varzim
# Processing request number 22 of 10 | kiama
# Processing request number 23 of 10 | abu kamal
# Processing request number 24 of 10 | preobrazheniye
# Processing request number 25 of 10 | eyl
# Processing request number 26 of 10 | manali
# City not found.
# Processing request number 27 of 10 | kiruna
# Processing request number 28 of 10 | almaznyy
# Processing request number 29 of 10 | landshut
# Processing request number 30 of 10 | barcelos
# Processing request number 31 of 10 | ayorou
# Processing request number 32 of 10 | vila do maio
# Processing request number 33 of 10 | freire
# Processing request number 34 of 10 | arona
# Processing request number 35 of 10 | galle
# Processing request number 36 of 10 | bumba
# Processing request number 37 of 10 | marfino
# Processing request number 38 of 10 | maracacume
# Processing request number 39 of 10 | george
# Processing request number 40 of 10 | saint-pierre
# Processing request number 41 of 10 | warrnambool
# Processing request number 42 of 10 | beian
# Processing request number 43 of 10 | kurumkan
# Processing request number 44 of 10 | lozovo
# Processing request number 45 of 10 | senanga
# Processing request number 46 of 10 | talakan
# Processing request number 47 of 10 | santa luzia
# Processing request number 48 of 10 | paredon
# Processing request number 49 of 10 | praia
# Processing request number 50 of 10 | abidjan
# Processing request number 1 of 11 | yumen
# Processing request number 2 of 11 | kirakira
# Processing request number 3 of 11 | ayan
# Processing request number 4 of 11 | cockburn town
# Processing request number 5 of 11 | shingu
# Processing request number 6 of 11 | savonlinna
# Processing request number 7 of 11 | moose factory
# Processing request number 8 of 11 | rzhyshchiv
# Processing request number 9 of 11 | murakami
# Processing request number 10 of 11 | lavrentiya
# Processing request number 11 of 11 | oktyabrskiy
# Processing request number 12 of 11 | nishihara
# Processing request number 13 of 11 | neiafu
# Processing request number 14 of 11 | susanville
# Processing request number 15 of 11 | richards bay
# Processing request number 16 of 11 | arica
# Processing request number 17 of 11 | vanderhoof
# Processing request number 18 of 11 | bereda
# Processing request number 19 of 11 | kotel
# Processing request number 20 of 11 | grand-lahou
# Processing request number 21 of 11 | vanavara
# Processing request number 22 of 11 | lorengau
# Processing request number 23 of 11 | port hardy
# City not found.
# Processing request number 24 of 11 | novokayakent
# Processing request number 25 of 11 | rio grande
# Processing request number 26 of 11 | pundaguitan
# Processing request number 27 of 11 | qaqortoq
# Processing request number 28 of 11 | nantucket
# Processing request number 29 of 11 | valenca
# Processing request number 30 of 11 | sepuka
# Processing request number 31 of 11 | coxim
# Processing request number 32 of 11 | acapulco
# Processing request number 33 of 11 | mananjary
# Processing request number 34 of 11 | kiunga
# Processing request number 35 of 11 | jeremie
# Processing request number 36 of 11 | aquiraz
# Processing request number 37 of 11 | fort nelson
# Processing request number 38 of 11 | santa marta
# Processing request number 39 of 11 | asau
# Processing request number 40 of 11 | naze
# Processing request number 41 of 11 | samarai
# Processing request number 42 of 11 | los llanos de aridane
# Processing request number 43 of 11 | carhuamayo
# Processing request number 44 of 11 | ahuimanu
# Processing request number 45 of 11 | brokopondo
# Processing request number 46 of 11 | alice springs
# Processing request number 47 of 11 | marawi
# Processing request number 48 of 11 | dong hoi
# City not found.
# Processing request number 49 of 11 | smithers
# Processing request number 50 of 11 | shelton
# Processing request number 1 of 12 | tolbazy
# Processing request number 2 of 12 | roberval
# Processing request number 3 of 12 | sasykoli
# Processing request number 4 of 12 | sorland
# Processing request number 5 of 12 | krasavino
# Processing request number 6 of 12 | odesskoye
# Processing request number 7 of 12 | pangody
# Processing request number 8 of 12 | canutama
# Processing request number 9 of 12 | iraucuba
# Processing request number 10 of 12 | the valley
# Processing request number 11 of 12 | launceston
# City not found.
# Processing request number 12 of 12 | cap-aux-meules
# Processing request number 13 of 12 | hidalgo
# Processing request number 14 of 12 | bairiki
# Processing request number 15 of 12 | along
# Processing request number 16 of 12 | fukue

# %%
#Save city results into dataframe
DateTime = pd.to_datetime(Datelist, unit='s')
Weatherdata = pd.DataFrame ({"City":Cityname, "Latitude":Latlist, "Longitude":Lnglist, 
                             "Maximum Temperature (F)":Maxtemplist,
                             "Humidity":Humlist, "Cloudiness":Cloudlist, 
                             "Wind Speed":Windlist, "Country":Countrylist,
                             "Date and Time":DateTime})
#Had to do a print line to see where I was missing data
#print (len(Cityname), len(Latlist), len(Lnglist), len(Maxtemplist),len(Humlist),len(Cloudlist),len(Windlist),len(Countrylist),len(Datelist))
Weatherdata.to_csv("Weatherdata.csv", index = False)
Weatherdata.head()
# Out:
#          City  Latitude  Longitude  Maximum Temperature (F)  Humidity  \
# 0      Bethel   41.3712   -73.4140                    22.05        68
# 1     Rikitea  -23.1203  -134.9692                    77.38        64
# 2     Mataura  -46.1927   168.8643                    73.87        57
# 3  Nikolskoye   59.7035    30.7861                    26.49        96
# 4     Mindelo   16.8901   -24.9804                    69.35        60
#
#    Cloudiness  Wind Speed Country       Date and Time
# 0           0        0.00      US 2022-01-31 04:31:56
# 1         100        5.79      PF 2022-01-31 04:31:56
# 2          92        4.94      NZ 2022-01-31 04:31:57
# 3         100        5.06      RU 2022-01-31 04:31:57
# 4          75       20.71      CV 2022-01-31 04:31:57

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
Humidity_filter = Weatherdata[Weatherdata["Humidity"]>100]
print (Humidity_filter)
#There are no cities in our dataset that have a humidity over 100
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Longitude, Maximum Temperature (F), Humidity, Cloudiness, Wind Speed, Country, Date and Time]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(8,6))
plt.scatter(Weatherdata["Latitude"], Weatherdata ["Maximum Temperature (F)"], color = "darkmagenta", edgecolor = "black")
plt.title("City Latitude versus Maximum Temperature (31-01-2022)")
plt.xlabel("City Latitude")
plt.ylabel("Temperature (F)")
plt.ylim(-40,110)
plt.grid()
plt.show()
print ("This graph is the comparison of the cities at their latitudes in comparison to the highest recorded temperature. Looking at the graph we can see there is a loose correlation between the two - the closer the latitude is to the equator the higher the temperature recorded.")
# Out:
# This graph is the comparison of the cities at their latitudes in comparison to the highest recorded temperature. Looking at the graph we can see there is a loose correlation between the two - the closer the latitude is to the equator the higher the temperature recorded.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(8,6))
plt.scatter(Weatherdata["Latitude"], Weatherdata ["Humidity"], color = "orchid", edgecolor = "black")
plt.title("City Latitude versus Humidity (31-01-2022)")
plt.xlabel("City Latitude")
plt.ylabel("Humidity")
plt.ylim(0,110)
plt.grid()
plt.show()
print ("This graph is a comparison of the city latitudes and the recorded humidity. There is no discernible correlation between the two that can be seen from this graph.")
# Out:
# This graph is a comparison of the city latitudes and the recorded humidity. There is no discernible correlation between the two that can be seen from this graph.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(8,6))
plt.scatter(Weatherdata["Latitude"], Weatherdata ["Cloudiness"], color = "deeppink", edgecolor = "black")
plt.title("City Latitude versus Cloudiness (31-01-2022)")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness (%)")
plt.ylim(-10,110)
plt.grid()
plt.show()
print("In the graph above we can see the city latitude in comparison to the cloudiness measured at each location. It does not look like there is any discernible correlation between the two variables.")
# Out:
# In the graph above we can see the city latitude in comparison to the cloudiness measured at each location. It does not look like there is any discernible correlation between the two variables.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(8,6))
plt.scatter(Weatherdata["Latitude"], Weatherdata ["Wind Speed"], color = "mediumvioletred", edgecolor = "black")
plt.title("City Latitude versus Wind Speed (31-01-2022)")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.show()
print ("This graph shows city latitude and the wind speed measured at these locations. This chart has little to no correlation present between these two values. There are cities measured at similar latitudes that have very different wind speeds measured.")
# Out:
# This graph shows city latitude and the wind speed measured at these locations. This chart has little to no correlation present between these two values. There are cities measured at similar latitudes that have very different wind speeds measured.

# %% [markdown]
# ## Linear Regression

# %%
Northdf = Weatherdata[Weatherdata["Latitude"]>=0]
Southdf = Weatherdata[Weatherdata["Latitude"]<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.figure(figsize=(8,6))
x_values = Northdf["Latitude"]
y_values = Northdf["Maximum Temperature (F)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker = "o", facecolor = "plum")
plt.plot(x_values,regress_values,color = "purple")
plt.annotate(line_eq,(6,10),fontsize=15,color = "purple")
plt.title("Northern Hemisphere: Maximum Temperature versus Latitude Linear Regression (31-01-2022)")
plt.xlabel("City Latitude")
plt.ylabel("Temperature (F)")
print(f"The r-squared is: {rvalue**2}")
plt.grid()
plt.show()
print("The graph below shows the northern hemisphere cities and the maximum temperatures recorded at these cities. Looking at our correlation coefficient of 0.787.. we can see there is a very strong correlation between the two."
      "Using the equation we can see that for every degree a city moves up in latitude the temperature will drop by 1.35 degrees.")
# Out:
# The r-squared is: 0.7876147583370552
# The graph below shows the northern hemisphere cities and the maximum temperatures recorded at these cities. Looking at our correlation coefficient of 0.787.. we can see there is a very strong correlation between the two.Using the equation we can see that for every degree a city moves up in latitude the temperature will drop by 1.35 degrees.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.figure(figsize=(8,6))
x_values = Southdf["Latitude"]
y_values = Southdf["Maximum Temperature (F)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker = "o", facecolor = "mediumturquoise")
plt.plot(x_values,regress_values,color = "darkslategray")
plt.title("Southern Hemisphere: Maximum Temperature versus Latitude Linear Regression (31-01-2022)")
plt.xlabel("City Latitude")
plt.ylabel("Temperature (F)")
plt.annotate(line_eq,(-50,95),fontsize=15,color = "darkslategray")
print(f"The r-squared is: {rvalue**2}")
plt.grid()
plt.show()
print ("The graph below shows the southern hemisphere cities and the maximum temperatures recorded at these cities. Looking at our correlation coefficient of 0.084... we can see there is very little correlation between the two variables")
# Out:
# The r-squared is: 0.08452353899592276
# The graph below shows the southern hemisphere cities and the maximum temperatures recorded at these cities. Looking at our correlation coefficient of 0.084... we can see there is very little correlation between the two variables

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(8,6))
x_values = Northdf["Latitude"]
y_values = Northdf["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker = "o", facecolor = "lightcoral")
plt.plot(x_values,regress_values,color = "darkred")
plt.title("Northern Hemisphere: Humidity versus Latitude Linear Regression (31-01-2022)")
plt.xlabel("City Latitude")
plt.ylabel("Humiditym (%)")
plt.annotate(line_eq,(50,30),fontsize=15,color = "darkred")
print(f"The r-squared is: {rvalue**2}")
plt.grid()
plt.show()
print ("This graph below shows the northern hemisphere cities and the humidity measured at the locations. We can take a quick look at the graph to see there is no correlation between the two and we can back up our findings with our correlation coefficient. ")
# Out:
# The r-squared is: 0.1696085915341691
# This graph below shows the northern hemisphere cities and the humidity measured at the locations. We can take a quick look at the graph to see there is no correlation between the two and we can back up our findings with our correlation coefficient.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(8,6))
x_values = Southdf["Latitude"]
y_values = Southdf["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker = "o", facecolor = "orange")
plt.plot(x_values,regress_values,color = "orangered")
plt.title("Southern Hemisphere: Humidity (%) versus Latitude Linear Regression (31-01-2022)")
plt.xlabel("City Latitude")
plt.ylabel("Humidity (%)")
plt.annotate(line_eq,(-25,30),fontsize=15,color = "orangered")
print(f"The r-squared is: {rvalue**2}")
plt.grid()
plt.show()
print ("This graph below shows the southern hemisphere cities and the humidity measured at the locations. We can take a quick look at the graph to see there is no correlation between the two and we can back up our findings with our correlation coefficient. ")
# Out:
# The r-squared is: 0.13428775609449378
# This graph below shows the southern hemisphere cities and the humidity measured at the locations. We can take a quick look at the graph to see there is no correlation between the two and we can back up our findings with our correlation coefficient.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(8,6))
x_values = Northdf["Latitude"]
y_values = Northdf["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker = "o", facecolor = "lightgreen")
plt.plot(x_values,regress_values,color = "darkgreen")
plt.title("Northern Hemisphere: Cloudiness versus Latitude Linear Regression (31-01-2022)")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(50,30),fontsize=15,color = "darkgreen")
print(f"The r-squared is: {rvalue**2}")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.0971143456301611

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(8,6))
x_values = Southdf["Latitude"]
y_values = Southdf["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker = "o", facecolor = "pink")
plt.plot(x_values,regress_values,color = "darkcyan")
plt.title("Southern Hemisphere: Cloudiness versus Latitude Linear Regression (31-01-2022)")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(-50,95),fontsize=15,color = "darkcyan")
print(f"The r-squared is: {rvalue**2}")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.1610258084803407

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(8,6))
x_values = Northdf["Latitude"]
y_values = Northdf["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker = "o", facecolor = "palevioletred")
plt.plot(x_values,regress_values,color = "darkmagenta")
plt.title("Northern Hemisphere: Wind Speed versus Latitude Linear Regression (31-01-2022)")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.annotate(line_eq,(10,30),fontsize=15,color = "darkmagenta")
print(f"The r-squared is: {rvalue**2}")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.0036382115054312053

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(8,6))
x_values = Southdf["Latitude"]
y_values = Southdf["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker = "o", facecolor = "paleturquoise")
plt.plot(x_values,regress_values,color = "darkblue")
plt.title("Southern Hemisphere: Wind Speed versus Latitude Linear Regression (31-01-2022)")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.annotate(line_eq,(-50,17),fontsize=15,color = "darkblue")
print(f"The r-squared is: {rvalue**2}")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.051651740557273874
